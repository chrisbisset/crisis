# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Chris Bisset**
# Architect

# %% [markdown]
# *I am an architect (construction) based London, interested in learning programming to move in the data science field.
# I am interested in learning complex analytical skills to ask questions to and draw insights from large data sets.*

# %% [markdown]
# ### Experiments with 3D plotting graphs

# %%
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')

fig = plt.figure(figsize = (10,10))
ax = plt.axes(projection='3d')
plt.show()

# %%
fig = plt.figure(figsize = (10,10))
ax = plt.axes(projection='3d')
ax.grid()
r = 1
s = 100

for p in range (s):
    radians = 2*math.pi * p/s
    for y in range (-r, r+1):
        z = math.sqrt(r**2-y**2) * math.sin(radians)
        x = math.sqrt(r**2-y**2) * math.cos(radians)

ax.scatter(x, y, z, c = 'r')
ax.set_title('3D Scatter Plot')
plt.show()

# %%
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection='3d')
ax.grid()
t = np.arange(0, 10*np.pi, np.pi/50)
x = np.sin(t)
y = np.cos(t)

ax.plot3D(x, y, t)
ax.set_title('3D Parametric Plot')

# Set axes label
ax.set_xlabel('x', labelpad=20)
ax.set_ylabel('y', labelpad=20)
ax.set_zlabel('t', labelpad=20)

plt.show()

# %%
def strike(text):
    return ''.join([u'\u0336{}'.format(c) for c in text])

print(strike('strikethrough text'))
# Out:
# ̶s̶t̶r̶i̶k̶e̶t̶h̶r̶o̶u̶g̶h̶ ̶t̶e̶x̶t

# %%
hyperlink text
